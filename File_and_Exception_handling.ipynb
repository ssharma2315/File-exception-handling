# %% [markdown]
# 1. What is the difference between interpreted and compiled languages?
# - Interpreted languages execute code line-by-line (e.g., Python), while compiled languages translate the entire code into machine language before execution (e.g., C, C++).
#
# 2. What is exception handling in Python?
# - It is a mechanism to handle errors during program execution using try, except, else, and finally blocks.
#
# 3. What is the purpose of the finally block in exception handling?
# - It ensures that certain code runs regardless of whether an exception occurred or not, often used for cleanup actions.
#
# 4. What is logging in Python?
# - Logging records messages (errors, info, warnings) during program execution for debugging and monitoring.
#
# 5. What is the significance of the __del__ method in Python?
# - It is a destructor method called when an object is about to be destroyed, often used to free resources.
#
# 6. What is the difference between import and from ... import in Python?
# - import module: Imports the whole module.
# -from module import name: Imports specific functions or classes directly.
#
# 7. How can you handle multiple exceptions in Python?
# - Using multiple except blocks or a single block with a tuple:
#
# -python
# -Copy
# -Edit
# -try:
#    - # code
# -except (TypeError, ValueError) as e:
# print(e)
# 8. What is the purpose of the with statement when handling files in Python?
# - It ensures the file is properly closed automatically after operations, even if exceptions occur.
#
# 9. What is the difference between multithreading and multiprocessing?
# - Multithreading: Multiple threads in the same process (shares memory).
#
# - Multiprocessing: Separate processes (independent memory), better for     CPU-bound tasks.
#
# 10. What are the advantages of using logging in a program?
# - Tracks program execution
#
# -  Helps in debugging
#
# -  Stores error messages
#
# -  Can log to files or external systems
#
# 11. What is memory management in Python?
# -  It refers to the process of allocating and releasing memory using automatic garbage collection.
#
# 12. What are the basic steps involved in exception handling in Python?
# - Try: Code block to test
#
# - Except: Handle exceptions
#
# - Else: Executes if no error
#
# - Finally: Executes always
#
# 13. Why is memory management important in Python?
# - Efficient memory management prevents memory leaks, improves performance, and avoids crashes.
#
# 14. What is the role of try and except in exception handling?
# - try: Contains code that may raise an exception
#
# - except: Handles the exception if one occurs
#
# 15. How does Python's garbage collection system work?
# - It uses reference counting and a cyclic garbage collector to clean up unused objects automatically.
#
# 16. What is the purpose of the else block in exception handling?
# - It runs only if no exceptions occur in the try block.
#
# 17. What are the common logging levels in Python?
# - DEBUG, INFO, WARNING, ERROR, CRITICAL
#
# 18. What is the difference between os.fork() and multiprocessing in Python?
# - os.fork(): Unix-only, low-level
#
# - multiprocessing: Cross-platform, higher-level API for creating processes
#
# 19. What is the importance of closing a file in Python?
# - It frees up system resources and ensures all buffered data is properly written.
#
# 20. What is the difference between file.read() and file.readline() in Python?
# - read(): Reads the entire file
#
# - readline(): Reads one line at a time
#
# 21. What is the logging module in Python used for?
# - To track events and errors in a program by writing messages to files, console, etc.
#
# 22. What is the os module in Python used for in file handling?
# - It provides functions to interact with the operating system, such as file paths, directories, and file operations.
#
# 23. What are the challenges associated with memory management in Python?
# - Managing cyclic references
#
# - Memory leaks in long-running applications
#
# - Inefficient object references
#
# 24. How do you raise an exception manually in Python?
# Using the raise keyword:
#
# - python
# - Copy
# - Edit
# raise ValueError("Invalid value")
# 25. Why is it important to use multithreading in certain applications?
# - It improves performance in I/O-bound tasks (e.g., network calls) by running tasks concurrently.
#
# 1. How can you open a file for writing in Python and write a string to it?
# python
# Copy
# Edit
# # Open a file in write mode and write a string
# with open('output.txt', 'w') as file:
#     file.write('Hello, this is a test.')
# 2. Write a Python program to read the contents of a file and print each line
# python
# Copy
# Edit
# # Read contents of a file and print each line
# with open('output.txt', 'r') as file:
#     for line in file:
#         print(line.strip())
# 3. How would you handle a case where the file doesn't exist while trying to open it for reading?
# python
# Copy
# Edit
# # Handle file-not-found error using try-except
# try:
#     with open('non_existent.txt', 'r') as file:
#         print(file.read())
# except FileNotFoundError:
#     print("File not found.")
# 4. Write a Python script that reads from one file and writes its content to another file
# python
# Copy
# Edit
# # Copy content from one file to another
# with open('source.txt', 'r') as src, open('destination.txt', 'w') as dest:
#     for line in src:
#         dest.write(line)
# 5. How would you catch and handle division by zero error in Python?
# python
# Copy
# Edit
# # Handle division by zero using try-except
# try:
#     result = 10 / 0
# except ZeroDivisionError:
#     print("Cannot divide by zero.")
# 6. Write a Python program that logs an error message to a log file when a division by zero exception occurs
# python
# Copy
# Edit
# # Log error when division by zero occurs
# import logging
#
# logging.basicConfig(filename='error.log', level=logging.ERROR)
# try:
#     x = 10 / 0
# except ZeroDivisionError as e:
#     logging.error("Division by zero error: %s", e)
# 7. How do you log information at different levels in Python using the logging module?
# python
# Copy
# Edit
# # Logging messages at different levels
# import logging
#
# logging.basicConfig(level=logging.DEBUG)
# logging.info("This is an info message.")
# logging.warning("This is a warning.")
# logging.error("This is an error.")
# 8. Write a program to handle a file opening error using exception handling
# python
# Copy
# Edit
# # Handle file open error
# try:
#     f = open('file.txt', 'r')
# except IOError:
#     print("File cannot be opened.")
# 9. How can you read a file line by line and store its content in a list in Python?
# python
# Copy
# Edit
# # Store file lines in a list
# with open('data.txt', 'r') as file:
#     lines = file.readlines()
# print(lines)
# 10. How can you append data to an existing file in Python?
# python
# Copy
# Edit
# # Append to a file
# with open('data.txt', 'a') as file:
#     file.write('\nAppended line.')
# 11. Write a program using try-except to handle missing dictionary key
# python
# Copy
# Edit
# # Handle KeyError
# my_dict = {'a': 1}
# try:
#     print(my_dict['b'])
# except KeyError:
#     print("Key not found.")
# 12. Write a program using multiple except blocks
# python
# Copy
# Edit
# # Handle multiple exception types
# try:
#     a = 10 / 0
#     b = [1, 2][5]
# except ZeroDivisionError:
#     print("Division error.")
# except IndexError:
#     print("Index error.")
# 13. How would you check if a file exists before attempting to read it?
# python
# Copy
# Edit
# # Check if file exists
# import os
# if os.path.exists('file.txt'):
#     with open('file.txt', 'r') as file:
#         print(file.read())
# else:
#     print("File does not exist.")
# 14. Write a program using the logging module for info and error
# python
# Copy
# Edit
# # Logging both info and error messages
# import logging
#
# logging.basicConfig(filename='logfile.log', level=logging.DEBUG)
# logging.info("This is an informational message.")
# logging.error("This is an error message.")
# 15. Write a program to print the content of a file and handle if it's empty
# python
# Copy
# Edit
# # Print file content or handle if empty
# with open('file.txt', 'r') as file:
#     content = file.read()
#     if not content:
#         print("File is empty.")
#     else:
#         print(content)
# 16. Demonstrate how to use memory profiling in Python
# python
# Copy
# Edit
# # Memory profiling using memory_profiler (install with pip install memory-profiler)
# from memory_profiler import profile
#
# @profile
# def sample():
#     a = [i for i in range(10000)]
#     return sum(a)
#
# sample()
# 17. Write a Python program to write a list of numbers to a file
# python
# Copy
# Edit
# # Write numbers to a file
# numbers = [1, 2, 3, 4, 5]
# with open('numbers.txt', 'w') as file:
#     for num in numbers:
#         file.write(f"{num}\n")
# 18. How would you implement logging to a file with rotation after 1MB?
# python
# Copy
# Edit
# # Logging with rotation after 1MB
# import logging
# from logging.handlers import RotatingFileHandler
#
# handler = RotatingFileHandler('rotating.log', maxBytes=1_000_000, backupCount=3)
# logging.basicConfig(handlers=[handler], level=logging.INFO)
# logging.info("Logging with rotation.")
# 19. Write a program that handles both IndexError and KeyError
# python
# Copy
# Edit
# # Handle IndexError and KeyError
# try:
#     lst = [1, 2]
#     val = lst[5]
#     d = {}
#     print(d['key'])
# except IndexError:
#     print("Index error occurred.")
# except KeyError:
#     print("Key error occurred.")
# 20. How would you open a file and read its contents using a context manager?
# python
# Copy
# Edit
# # Read file using context manager
# with open('file.txt', 'r') as file:
#     content = file.read()
#     print(content)
# 21. Write a Python program to count occurrences of a specific word in a file
# python
# Copy
# Edit
# # Count word occurrences
# word_to_count = 'python'
# count = 0
# with open('file.txt', 'r') as file:
#     for line in file:
#         count += line.lower().split().count(word_to_count.lower())
# print(f"'{word_to_count}' occurred {count} times.")
# 22. How can you check if a file is empty before reading it?
# python
# Copy
# Edit
# # Check if file is empty
# import os
# if os.stat('file.txt').st_size == 0:
#     print("File is empty.")
# else:
#     with open('file.txt', 'r') as file:
#         print(file.read())
# 23. Write a Python program that logs an error during file handling
# python
# Copy
# Edit
# # Log error during file handling
# import logging
#
# logging.basicConfig(filename='file_errors.log', level=logging.ERROR)
# try:
#     with open('nonexistent.txt', 'r') as file:
#         data = file.read()
# except Exception as e:
#     logging.error("Error occurred: %s", e)
